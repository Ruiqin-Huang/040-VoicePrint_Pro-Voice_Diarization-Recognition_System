# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
CLUSTERS_ERC = [
            {
                "segment_audio_file": "en1_Calling.wav",
                "x_coordinate": 164.53721618652344,
                "y_coordinate": 3.3086788654327393,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en1_Called.wav",
                "x_coordinate": 12.604552268981934,
                "y_coordinate": -73.93037414550781,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "en2_Calling.wav",
                "x_coordinate": 21.434585571289062,
                "y_coordinate": -89.9145736694336,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "en2_Called.wav",
                "x_coordinate": 188.48289489746094,
                "y_coordinate": 14.74768352508545,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en3_Calling.wav",
                "x_coordinate": 176.9148712158203,
                "y_coordinate": -32.83723449707031,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "en3_Called.wav",
                "x_coordinate": 174.5491180419922,
                "y_coordinate": -21.318302154541016,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "en4_Calling.wav",
                "x_coordinate": 16.09862518310547,
                "y_coordinate": -100.29934692382812,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "en4_Called.wav",
                "x_coordinate": 183.40492248535156,
                "y_coordinate": 24.821504592895508,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en5_Calling.wav",
                "x_coordinate": 166.1902618408203,
                "y_coordinate": -30.525314331054688,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "en5_Called.wav",
                "x_coordinate": 173.78466796875,
                "y_coordinate": 5.6718430519104,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en6_Calling.wav",
                "x_coordinate": 28.799402236938477,
                "y_coordinate": -100.82572937011719,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "en6_Called.wav",
                "x_coordinate": -145.04769897460938,
                "y_coordinate": 56.53446960449219,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "en7_Calling.wav",
                "x_coordinate": 34.47712707519531,
                "y_coordinate": -90.07359313964844,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "en7_Called.wav",
                "x_coordinate": -136.87020874023438,
                "y_coordinate": 61.40237808227539,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "en8_Calling.wav",
                "x_coordinate": 149.43508911132812,
                "y_coordinate": 11.131802558898926,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en8_Called.wav",
                "x_coordinate": 189.93472290039062,
                "y_coordinate": -10.408084869384766,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "en9_Calling.wav",
                "x_coordinate": 160.42523193359375,
                "y_coordinate": 17.034929275512695,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en9_Called.wav",
                "x_coordinate": 152.59400939941406,
                "y_coordinate": 32.931602478027344,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "ru1_Calling.wav",
                "x_coordinate": -113.22210693359375,
                "y_coordinate": -48.51534652709961,
                "cluster_id": 9
            },
            {
                "segment_audio_file": "ru1_Called.wav",
                "x_coordinate": -116.95182037353516,
                "y_coordinate": -137.21690368652344,
                "cluster_id": 6
            },
            {
                "segment_audio_file": "ru2_Calling.wav",
                "x_coordinate": -94.75450897216797,
                "y_coordinate": -12.268905639648438,
                "cluster_id": 10
            },
            {
                "segment_audio_file": "ru2_Called.wav",
                "x_coordinate": -103.42278289794922,
                "y_coordinate": -131.86782836914062,
                "cluster_id": 6
            },
            {
                "segment_audio_file": "ru3_Calling.wav",
                "x_coordinate": -113.69950866699219,
                "y_coordinate": -66.56613159179688,
                "cluster_id": 9
            },
            {
                "segment_audio_file": "ru3_Called.wav",
                "x_coordinate": -126.42084503173828,
                "y_coordinate": -77.66284942626953,
                "cluster_id": 9
            },
            {
                "segment_audio_file": "ru4_Calling.wav",
                "x_coordinate": -108.02845764160156,
                "y_coordinate": -119.88898468017578,
                "cluster_id": 6
            },
            {
                "segment_audio_file": "ru4_Called.wav",
                "x_coordinate": -156.17604064941406,
                "y_coordinate": 19.60299301147461,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "ru5_Calling.wav",
                "x_coordinate": -167.82882690429688,
                "y_coordinate": 39.00430679321289,
                "cluster_id": 2
            },
            {
                "segment_audio_file":

                "cluster_id": 3
            },
            {
                "segment_audio_file": "zh9_Called.wav",
                "x_coordinate": 12.771740913391113,
                "y_coordinate": -155.63772583007812,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "zh10_Calling.wav",
                "x_coordinate": -33.03623962402344,
                "y_coordinate": 95.31424713134766,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "zh10_Called.wav",
                "x_coordinate": -51.73805618286133,
                "y_coordinate": -132.23431396484375,
                "cluster_id": 1
            }
        ]


CLUSTER_TEST = [
            {
                "segment_audio_file": "en1_Calling.wav",
                "x_coordinate": 289.5436706542969,
                "y_coordinate": 6.546466827392578,
                "cluster_id": 0
            },
            {
                "segment_audio_file": "en1_Called.wav",
                "x_coordinate": -193.0330810546875,
                "y_coordinate": 370.4133605957031,
                "cluster_id": 3
            },
            {
                "segment_audio_file": "en2_Calling.wav",
                "x_coordinate": -85.539794921875,
                "y_coordinate": 345.3912658691406,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "en2_Called.wav",
                "x_coordinate": 336.03033447265625,
                "y_coordinate": -84.62196350097656,
                "cluster_id": 4
            },
            {
                "segment_audio_file": "ru4_Calling.wav",
                "x_coordinate": -370.9107360839844,
                "y_coordinate": 194.38302612304688,
                "cluster_id": 5
            },
            {
                "segment_audio_file": "ru4_Called.wav",
                "x_coordinate": -244.9554443359375,
                "y_coordinate": 108.69331359863281,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "ru8_Calling.wav",
                "x_coordinate": -28.954357147216797,
                "y_coordinate": -38.00139236450195,
                "cluster_id": 6
            },
            {
                "segment_audio_file": "ru8_Called.wav",
                "x_coordinate": -143.91009521484375,
                "y_coordinate": 68.85246276855469,
                "cluster_id": 2
            },
            {
                "segment_audio_file": "zh3_Calling.wav",
                "x_coordinate": 199.1025848388672,
                "y_coordinate": 246.3430938720703,
                "cluster_id": 7
            },
            {
                "segment_audio_file": "zh3_Called.wav",
                "x_coordinate": -196.46864318847656,
                "y_coordinate": -134.05606079101562,
                "cluster_id": 8
            },
            {
                "segment_audio_file": "zh10_Calling.wav",
                "x_coordinate": -57.012779235839844,
                "y_coordinate": 176.6416778564453,
                "cluster_id": 1
            },
            {
                "segment_audio_file": "zh10_Called.wav",
                "x_coordinate": 177.3943328857422,
                "y_coordinate": 112.68025207519531,
                "cluster_id": 0
            }
        ]

# %%
def show_clusters(clusters):
    # 提取坐标和类别
    x = np.array([item['x_coordinate'] for item in clusters])
    y = np.array([item['y_coordinate'] for item in clusters])
    labels = np.array([item['cluster_id'] for item in clusters])
    files = [item['segment_audio_file'] for item in clusters]

    # 自动生成颜色，支持1~100类
    num_classes = len(set(labels))
    cmap = plt.get_cmap('tab20' if num_classes <= 20 else 'tab20b')
    colors = [cmap(l % cmap.N) for l in labels]

    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(x, y, c=labels, cmap=cmap, s=80, edgecolors='k', alpha=0.7)

    # 标注文件名
    for xi, yi, fname in zip(x, y, files):
        plt.text(xi, yi, fname, fontsize=8, ha='right', va='bottom', alpha=0.7)

    plt.title(f'Cluster Visualization ({num_classes} classes)')
    plt.xlabel('t-SNE X')
    plt.ylabel('t-SNE Y')
    plt.grid(True, linestyle='--', alpha=0.3)
    plt.colorbar(scatter, label='Cluster ID')
    plt.tight_layout()
    plt.show()

# 调用可视化
show_clusters(CLUSTER_TEST)

# %%
import numpy as np

# 两个点的坐标
p1 = np.array([39.24646759033203, 107.85839080810547])
p2 = np.array([24.55996322631836, 99.42717742919922])

# 计算欧氏距离
distance_threshold = np.linalg.norm(p1 - p2)
print(distance_threshold)  # 输出距离，可直接用于AgglomerativeClustering
# Out:
# 16.934543674833414
